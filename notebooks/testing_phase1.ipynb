# %%
import os
import cv2
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
from keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
# %matplotlib inline

# %%
img = cv2.imread('../data/processed/test/class_2/1debff5538d7402188a3808bf07e6351.jpg')
# C:\Users\Dapo\OneDrive\Desktop\youtube_dl\deep_learning\data\processed\test\class_2\1debff5538d7402188a3808bf07e6351.jpg

# %%
# img

# %%
model = load_model('../saved_models/trained.h5')

# %%
plt.imshow(img)

# %%
def pred(img):
    img=cv2.resize(img,(255,255))
    img=np.array(img)
    img=np.expand_dims(img, axis=0)
    pred=model.predict(img)
    pred=(str(pred))

# %%
demo=pred(img)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
print(demo)
# Out:
# None
